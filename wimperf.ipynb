# %% [markdown]
# In this notebook the frequencies of W plus yiqtol are counted per book.

# %%
import sys, collections, os

# %%
from tf.fabric import Fabric
TF = Fabric(modules='hebrew/etcbc4c')
# Out:
# This is Text-Fabric 2.3.6
# Api reference : https://github.com/ETCBC/text-fabric/wiki/Api
# Tutorial      : https://github.com/ETCBC/text-fabric/blob/master/docs/tutorial.ipynb
# Data sources  : https://github.com/ETCBC/text-fabric-data
# Data docs     : https://etcbc.github.io/text-fabric-data
# Shebanq docs  : https://shebanq.ancient-data.org/text
# Slack team    : https://shebanq.slack.com/signup
# Questions? Ask shebanq@ancient-data.org for an invite to Slack
# 108 features found and 0 ignored

# %% [markdown]
# Activate relevant linguistic features

# %%
api = TF.load('''
    lex language sp vt
''')
# Out:
#   0.00s loading features ...
#    |     0.26s B lex                  from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.37s B language             from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.38s B sp                   from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.27s B vt                   from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.00s Feature overview: 102 for nodes; 5 for edges; 1 configs; 7 computed
#     13s All features loaded/computed - for details use loadLog()

# %%
api.loadLog()
api.makeAvailableIn(globals())
# Out:
#    |     0.06s B otype                from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     1.59s B oslots               from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s M otext                from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.02s B book                 from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B chapter              from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B verse                from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.37s B g_cons               from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.52s B g_cons_utf8          from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.40s B g_lex                from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
#    |     0.57s B g_lex_utf8           from /Users/jAir/github/text-fabric-data/hebrew/etcbc4c
# ...

# %% [markdown]
# We start with the clause as basic unit, because W and the yiqtol verb should occur in one clause.

# %%
wimperf_dict = collections.defaultdict(int)

for cl in F.otype.s('clause'): #walk through all the clauses
    words = L.d(cl, 'word')
    if F.language.v(words[0]) == 'hbo' and F.lex.v(words[0]) == 'W': #does clause start with 'W' and is it in Hebrew?
        if len(words) > 1: # is the phrase longer than one word
            if F.sp.v(words[1]) == 'verb' and F.vt.v(words[1]) == 'impf': #is the second word a verb in imperfect?
                book = T.sectionFromNode(words[0])[0] #in which book does it occur?
                wimperf_dict[book] += 1 # add to dictionary
                print(T.sectionFromNode(words[0]))
    
print(wimperf_dict) #this is printed after the individual attestations
# Out:
# ('Genesis', 1, 6)
# ('Genesis', 1, 9)
# ('Genesis', 1, 26)
# ('Genesis', 9, 26)
# ('Genesis', 9, 27)
# ('Genesis', 9, 27)
# ('Genesis', 11, 3)
# ('Genesis', 11, 4)
# ('Genesis', 11, 7)
# ('Genesis', 12, 2)
# ('Genesis', 12, 2)
# ('Genesis', 12, 2)
# ('Genesis', 12, 3)
# ('Genesis', 13, 9)
# ('Genesis', 13, 9)
# ('Genesis', 17, 2)
# ('Genesis', 17, 2)
# ('Genesis', 18, 5)
# ('Genesis', 18, 21)
# ('Genesis', 18, 30)
# ('Genesis', 18, 32)
# ('Genesis', 19, 5)
# ('Genesis', 19, 20)
# ('Genesis', 19, 32)
# ('Genesis', 19, 32)
# ('Genesis', 19, 34)
# ('Genesis', 20, 7)
# ('Genesis', 22, 5)
# ('Genesis', 22, 5)
# ('Genesis', 22, 17)
# ('Genesis', 23, 4)
# ('Genesis', 23, 9)
# ('Genesis', 23, 13)
# ('Genesis', 24, 3)
# ('Genesis', 24, 14)
# ('Genesis', 24, 49)
# ('Genesis', 24, 51)
# ('Genesis', 24, 56)
# ('Genesis', 24, 57)
# ('Genesis', 24, 60)
# ('Genesis', 26, 3)
# ('Genesis', 26, 3)
# ('Genesis', 26, 28)
# ('Genesis', 27, 4)
# ('Genesis', 27, 7)
# ('Genesis', 27, 7)
# ...

# %%
csvh = open('wimperf.csv', "w")
header = ['book', 'count']
csvh.write('{}\n'.format(','.join(header)))
for he in wimperf_dict:
    line = wimperf_dict[he]
    csvh.write('{}\n'.format(','.join(line)))
csvh.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9db771258ca0> in <module>()
#       4 for he in wimperf_dict:
#       5     line = wimperf_dict[he]
# ----> 6     csvh.write('{}\n'.format(','.join(line)))
#       7 csvh.close()
#
# TypeError: can only join an iterable
